# %% [markdown]
# **Estimation And Confidence Intervals**

# %% [markdown]
# **Data**
#
# A total of 15 print-heads were randomly selected and tested until failure. The durability of each print-head (in millions of characters) was recorded as follows:
#
# 1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29

# %%
data=[1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29]

# %%
import numpy as np
data=np.array(data)
data
# Out:
# array([1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.2 ,
#        1.33, 1.18, 1.22, 1.29])

# %% [markdown]
# **Assignment Tasks**
#
# a. Build 99% Confidence Interval Using Sample Standard Deviation
# Assuming the sample is representative of the population, construct a 99% confidence interval for the mean number of characters printed before the print-head fails using the sample standard deviation. Explain the steps you take and the rationale behind using the t-distribution for this task.

# %%
import scipy.stats as stats

# %%
sample_mean=np.mean(data)
sample_std=np.std(data,ddof=1)
sample_len=len(data)
df=sample_len-1
cofidence_level=0.99
alpha=1-cofidence_level
t_value=stats.t.ppf(1-alpha/2,df)
sea=sample_std/np.sqrt(sample_len)
margin_of_error=t_value*sea
lower_limit=sample_mean-margin_of_error
upper_limit=sample_mean+margin_of_error

print('Building 99% Confidence Interval Using Sample Standard Deviation')
print(f"Sample Mean {sample_mean:2f} of millions")
print(f"Sample Standard Deviation {sample_std:2f} of millions")
print(f"Sample Length {sample_len}")
print(f"Degree of Freedom {df}")
print(f"Confidence Level {cofidence_level*100:2f}%")
print(f"Alpha {alpha:2f}")
print(f"T Value {t_value:2f} of millions")
print(f"Standard Error of the Mean {sea:2f}")
print(f"Margin of Error {margin_of_error:2f}")
print(f"Lower Limit {lower_limit:2f} of millions")
print(f"Upper Limit {upper_limit:2f} of millions")
# Out:
# Building 99% Confidence Interval Using Sample Standard Deviation
# Sample Mean 1.238667 of millions
# Sample Standard Deviation 0.193164 of millions
# Sample Length 15
# Degree of Freedom 14
# Confidence Level 99.000000%
# Alpha 0.010000
# T Value 2.976843 of millions
# Standard Error of the Mean 0.049875
# Margin of Error 0.148469
# Lower Limit 1.090197 of millions
# Upper Limit 1.387136 of millions

# %% [markdown]
# b. Build 99% Confidence Interval Using Known Population Standard Deviation
# If it were known that the population standard deviation is 0.2 million characters, construct a 99% confidence interval for the mean number of characters printed before failure.

# %%
p_std_dev=0.2

z_value=stats.norm.ppf(1-alpha/2)
std_mean_err=sample_std/np.sqrt(sample_len)
moe_z = z_value*std_mean_err

lower_limit=sample_mean-moe_z
upper_limit=sample_mean+moe_z


print('Build 99% Confidence Interval Using population standard deviation')
print(f'stdandard_dev {p_std_dev} of millions')
print(f'z_value {z_value} ')
print(f'std_mean_err {std_mean_err} ')
print(f'moe_z {moe_z} ')
print(f'lower_limit {lower_limit} of millions')
print(f'upper_limit {upper_limit} of millions')
# Out:
# Build 99% Confidence Interval Using population standard deviation
# stdandard_dev 0.2 of millions
# z_value 2.5758293035489004
# std_mean_err 0.04987476379384733
# moe_z 0.1284688780877717
# lower_limit 1.110197788578895 of millions
# upper_limit 1.3671355447544382 of millions
